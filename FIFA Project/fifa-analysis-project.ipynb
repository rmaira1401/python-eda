# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa =pd.read_csv('fifa data.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 3     200389  https://sofifa.com/player/200389/jan-oblak/20/...
# 4     183277  https://sofifa.com/player/183277/eden-hazard/2...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   32  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# 2          Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 3           J. Oblak                            Jan Oblak   26  1993-01-07
# 4          E. Hazard                          Eden Hazard   28  1991-01-07
#
#    height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 0        170         72   Argentina         FC Barcelona  ...  68+2  66+2
# 1        187         83    Portugal             Juventus  ...  65+3  61+3
# 2        175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 3        188         87    Slovenia      Atlético Madrid  ...   NaN   NaN
# 4        175         74     Belgium          Real Madrid  ...  66+3  63+3
#
#     cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 0  66+2  66+2  68+2  63+2  52+2  52+2  52+2  63+2
# 1  61+3  61+3  65+3  61+3  53+3  53+3  53+3  61+3
# 2  61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4  63+3  63+3  66+3  61+3  49+3  49+3  49+3  61+3
#
# [5 rows x 104 columns]

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# age
# dob
# height_cm
# weight_kg
# nationality
# club
# overall
# potential
# value_eur
# wage_eur
# player_positions
# preferred_foot
# international_reputation
# weak_foot
# skill_moves
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# team_position
# team_jersey_number
# loaned_from
# joined
# contract_valid_until
# nation_position
# nation_jersey_number
# pace
# shooting
# passing
# dribbling
# defending
# physic
# gk_diving
# gk_handling
# gk_kicking
# gk_reflexes
# gk_speed
# gk_positioning
# player_traits
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# power_strength
# power_long_shots
# mentality_aggression
# mentality_interceptions
# mentality_positioning
# mentality_vision
# mentality_penalties
# mentality_composure
# defending_marking
# defending_standing_tackle
# defending_sliding_tackle
# goalkeeping_diving
# goalkeeping_handling
# goalkeeping_kicking
# goalkeeping_positioning
# goalkeeping_reflexes
# ls
# st
# rs
# lw
# lf
# cf
# rf
# rw
# lam
# cam
# ram
# lm
# lcm
# cm
# rcm
# rm
# lwb
# ldm
# cdm
# rdm
# rwb
# lb
# lcb
# cb
# rcb
# rb

# %%
fifa.shape
# Out:
# (18278, 104)

# %%
18278*104
# Out:
# 1900912

# %%
fifa['nationality'].value_counts()
# Out:
# nationality
# England                1667
# Germany                1216
# Spain                  1035
# France                  984
# Argentina               886
#                        ...
# Liberia                   1
# São Tomé & Príncipe       1
# Puerto Rico               1
# Bahrain                   1
# Indonesia                 1
# Name: count, Length: 162, dtype: int64

# %%
fifa['nationality'].value_counts()[0:10]
# Out:
# nationality
# England        1667
# Germany        1216
# Spain          1035
# France          984
# Argentina       886
# Brazil          824
# Italy           732
# Colombia        591
# Japan           453
# Netherlands     416
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5]
# Out:
# nationality
# England      1667
# Germany      1216
# Spain        1035
# France        984
# Argentina     886
# Name: count, dtype: int64

# %%
fifa['nationality'].value_counts()[0:5].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina'], dtype='object', name='nationality')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['nationality'].value_counts()[0:5].keys()), list(fifa['nationality'].value_counts()[0:5]),color='g')
plt.show()

# %%
player_salary=fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi    565000
# 1  Cristiano Ronaldo    405000
# 2          Neymar Jr    290000
# 3           J. Oblak    125000
# 4          E. Hazard    470000

# %%
player_salary=player_salary.sort_values(by=['wage_eur'], ascending=False)

# %%
player_salary.head()
# Out:
#            short_name  wage_eur
# 0            L. Messi    565000
# 4           E. Hazard    470000
# 1   Cristiano Ronaldo    405000
# 5        K. De Bruyne    370000
# 22       A. Griezmann    370000

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['short_name'])[0:5],list(player_salary['wage_eur'])[0:5], color=['blue','green','red','pink','orange'])
plt.show()

# %%
fifa['nationality']=='Germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18273    False
# 18274    False
# 18275    False
# 18276    False
# 18277    False
# Name: nationality, Length: 18278, dtype: bool

# %%
# Extracting Germany data
Germany=fifa[fifa['nationality']=='Germany']
Germany.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 31      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 37      188350  https://sofifa.com/player/188350/marco-reus/20...
# 49      178603  https://sofifa.com/player/178603/mats-hummels/...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 61      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
# 77      212190  https://sofifa.com/player/212190/niklas-sule/2...
# 109     235790  https://sofifa.com/player/235790/kai-havertz/2...
#
#         short_name              long_name  age         dob  height_cm  \
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 31        M. Neuer           Manuel Neuer   33  1986-03-27        193
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 37         M. Reus             Marco Reus   30  1989-05-31        180
# 49      M. Hummels          Mats  Hummels   30  1988-12-16        191
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 61      J. Kimmich         Joshua Kimmich   24  1995-02-08        176
# 70       T. Müller          Thomas Müller   29  1989-09-13        186
# 77         N. Süle            Niklas Süle   23  1995-09-03        195
# 109     K. Havertz            Kai Havertz   20  1999-06-11        188
#
#      weight_kg nationality                 club  ...   lwb   ldm   cdm   rdm  \
# 6           85     Germany         FC Barcelona  ...   NaN   NaN   NaN   NaN
# 31          92     Germany    FC Bayern München  ...   NaN   NaN   NaN   NaN
# 36          76     Germany          Real Madrid  ...  75+3  79+3  79+3  79+3
# 37          71     Germany    Borussia Dortmund  ...  69+3  65+3  65+3  65+3
# 49          94     Germany    Borussia Dortmund  ...  77+3  83+3  83+3  83+3
# 55          75     Germany      Manchester City  ...  65+2  59+2  59+2  59+2
# 61          73     Germany    FC Bayern München  ...  83+3  82+3  82+3  82+3
# 70          75     Germany    FC Bayern München  ...  69+3  68+3  68+3  68+3
# 77          97     Germany    FC Bayern München  ...  71+2  77+2  77+2  77+2
# 109         83     Germany  Bayer 04 Leverkusen  ...  65+2  63+2  63+2  63+2
#
#       rwb    lb   lcb    cb   rcb    rb
# 6     NaN   NaN   NaN   NaN   NaN   NaN
# 31    NaN   NaN   NaN   NaN   NaN   NaN
# 36   75+3  72+3  69+3  69+3  69+3  72+3
# 37   69+3  64+3  55+3  55+3  55+3  64+3
# 49   77+3  78+3  84+3  84+3  84+3  78+3
# 55   65+2  61+2  52+2  52+2  52+2  61+2
# 61   83+3  81+3  78+3  78+3  78+3  81+3
# 70   69+3  67+3  62+3  62+3  62+3  67+3
# 77   71+2  75+2  83+2  83+2  83+2  75+2
# 109  65+2  62+2  54+2  54+2  54+2  62+2
#
# [10 rows x 104 columns]

# %%
Germany.sort_values(by=['height_cm'], ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 8016      236831  https://sofifa.com/player/236831/aaron-seydel/...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 11859     167437  https://sofifa.com/player/167437/dominik-stroh...
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
#
#            short_name            long_name  age         dob  height_cm  \
# 8016        A. Seydel         Aaron Seydel   23  1996-02-07        199
# 1217         M. Esser        Michael Esser   31  1987-11-22        198
# 1389    L. Unnerstall      Lars Unnerstall   28  1990-07-20        198
# 11859  D. Stroh-Engel  Dominik Stroh-Engel   33  1985-11-27        197
# 13576    L. Watkowiak      Lukas Watkowiak   23  1996-03-06        197
#
#        weight_kg nationality                club  ...   lwb   ldm   cdm   rdm  \
# 8016          90     Germany     1. FSV Mainz 05  ...  46+2  43+2  43+2  43+2
# 1217          97     Germany         Hannover 96  ...   NaN   NaN   NaN   NaN
# 1389         103     Germany                 PSV  ...   NaN   NaN   NaN   NaN
# 11859         94     Germany  SpVgg Unterhaching  ...  39+2  45+2  45+2  45+2
# 13576        103     Germany  SV Wehen Wiesbaden  ...   NaN   NaN   NaN   NaN
#
#         rwb    lb   lcb    cb   rcb    rb
# 8016   46+2  44+2  43+2  43+2  43+2  44+2
# 1217    NaN   NaN   NaN   NaN   NaN   NaN
# 1389    NaN   NaN   NaN   NaN   NaN   NaN
# 11859  39+2  39+2  47+2  47+2  47+2  39+2
# 13576   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13576     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 1389      199833  https://sofifa.com/player/199833/lars-unnersta...
# 518       179783  https://sofifa.com/player/179783/ralf-fahrmann...
# 1217      200212  https://sofifa.com/player/200212/michael-esser...
# 77        212190  https://sofifa.com/player/212190/niklas-sule/2...
#
#           short_name        long_name  age         dob  height_cm  weight_kg  \
# 13576   L. Watkowiak  Lukas Watkowiak   23  1996-03-06        197        103
# 1389   L. Unnerstall  Lars Unnerstall   28  1990-07-20        198        103
# 518      R. Fährmann    Ralf Fährmann   30  1988-09-27        197         98
# 1217        M. Esser    Michael Esser   31  1987-11-22        198         97
# 77           N. Süle      Niklas Süle   23  1995-09-03        195         97
#
#       nationality                club  ...   lwb   ldm   cdm   rdm   rwb  \
# 13576     Germany  SV Wehen Wiesbaden  ...   NaN   NaN   NaN   NaN   NaN
# 1389      Germany                 PSV  ...   NaN   NaN   NaN   NaN   NaN
# 518       Germany        Norwich City  ...   NaN   NaN   NaN   NaN   NaN
# 1217      Germany         Hannover 96  ...   NaN   NaN   NaN   NaN   NaN
# 77        Germany   FC Bayern München  ...  71+2  77+2  77+2  77+2  71+2
#
#          lb   lcb    cb   rcb    rb
# 13576   NaN   NaN   NaN   NaN   NaN
# 1389    NaN   NaN   NaN   NaN   NaN
# 518     NaN   NaN   NaN   NaN   NaN
# 1217    NaN   NaN   NaN   NaN   NaN
# 77     75+2  83+2  83+2  83+2  75+2
#
# [5 rows x 104 columns]

# %%
Germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 36      182521  https://sofifa.com/player/182521/toni-kroos/20...
# 6       192448  https://sofifa.com/player/192448/marc-andre-te...
# 55      222492  https://sofifa.com/player/222492/leroy-sane/20...
# 146     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 70      189596  https://sofifa.com/player/189596/thomas-muller...
#
#         short_name              long_name  age         dob  height_cm  \
# 36        T. Kroos             Toni Kroos   29  1990-01-04        183
# 6    M. ter Stegen  Marc-André ter Stegen   27  1992-04-30        187
# 55         L. Sané             Leroy Sané   23  1996-01-11        183
# 146    I. Gündoğan         İlkay Gündoğan   28  1990-10-24        180
# 70       T. Müller          Thomas Müller   29  1989-09-13        186
#
#      weight_kg nationality               club  ...   lwb   ldm   cdm   rdm  \
# 36          76     Germany        Real Madrid  ...  75+3  79+3  79+3  79+3
# 6           85     Germany       FC Barcelona  ...   NaN   NaN   NaN   NaN
# 55          75     Germany    Manchester City  ...  65+2  59+2  59+2  59+2
# 146         80     Germany    Manchester City  ...  76+3  79+3  79+3  79+3
# 70          75     Germany  FC Bayern München  ...  69+3  68+3  68+3  68+3
#
#       rwb    lb   lcb    cb   rcb    rb
# 36   75+3  72+3  69+3  69+3  69+3  72+3
# 6     NaN   NaN   NaN   NaN   NaN   NaN
# 55   65+2  61+2  52+2  52+2  52+2  61+2
# 146  76+3  74+3  72+3  72+3  72+3  74+3
# 70   69+3  67+3  62+3  62+3  62+3  67+3
#
# [5 rows x 104 columns]

# %%
Germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 36        T. Kroos    330000
# 6    M. ter Stegen    250000
# 55         L. Sané    195000
# 146    I. Gündoğan    180000
# 70       T. Müller    170000

# %%
#shooting skills data
player_shooting = fifa[['short_name','shooting']]
player_shooting.sort_values(by=['shooting'],ascending=False).head()
# Out:
#             short_name  shooting
# 1    Cristiano Ronaldo      93.0
# 0             L. Messi      92.0
# 12             H. Kane      91.0
# 17           S. Agüero      90.0
# 205    F. Quagliarella      89.0

# %%
#defending skills
player_defending = fifa[['short_name','defending','nationality','club']]
player_defending.sort_values(by=['defending'],ascending=False).head()
# Out:
#       short_name  defending  nationality               club
# 16  G. Chiellini       90.0        Italy           Juventus
# 7    V. van Dijk       90.0  Netherlands          Liverpool
# 11  K. Koulibaly       89.0      Senegal             Napoli
# 35      D. Godín       89.0      Uruguay              Inter
# 49    M. Hummels       89.0      Germany  Borussia Dortmund

# %%
#real madrid data
real_madrid = fifa[fifa['club']=='Real Madrid']

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#     sofifa_id                                         player_url  \
# 4      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 8      177003  https://sofifa.com/player/177003/luka-modric/2...
# 36     182521  https://sofifa.com/player/182521/toni-kroos/20...
# 18     155862  https://sofifa.com/player/155862/sergio-ramos-...
# 46     165153  https://sofifa.com/player/165153/karim-benzema...
#
#       short_name            long_name  age         dob  height_cm  weight_kg  \
# 4      E. Hazard          Eden Hazard   28  1991-01-07        175         74
# 8      L. Modrić          Luka Modrić   33  1985-09-09        172         66
# 36      T. Kroos           Toni Kroos   29  1990-01-04        183         76
# 18  Sergio Ramos  Sergio Ramos García   33  1986-03-30        184         82
# 46    K. Benzema        Karim Benzema   31  1987-12-19        185         81
#
#    nationality         club  ...   lwb   ldm   cdm   rdm   rwb    lb   lcb  \
# 4      Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3  61+3  49+3
# 8      Croatia  Real Madrid  ...  81+3  81+3  81+3  81+3  81+3  79+3  72+3
# 36     Germany  Real Madrid  ...  75+3  79+3  79+3  79+3  75+3  72+3  69+3
# 18       Spain  Real Madrid  ...  80+3  84+3  84+3  84+3  80+3  82+3  87+3
# 46      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3  58+3  54+3
#
#       cb   rcb    rb
# 4   49+3  49+3  61+3
# 8   72+3  72+3  79+3
# 36  69+3  69+3  72+3
# 18  87+3  87+3  82+3
# 46  54+3  54+3  58+3
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 100     173731  https://sofifa.com/player/173731/gareth-bale/2...
# 106     198710  https://sofifa.com/player/198710/james-rodrigu...
# 4       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 46      165153  https://sofifa.com/player/165153/karim-benzema...
# 161     232432  https://sofifa.com/player/232432/luka-jovic/20...
#
#        short_name                    long_name  age         dob  height_cm  \
# 100       G. Bale            Gareth Frank Bale   29  1989-07-16        185
# 106  J. Rodríguez  James David Rodríguez Rubio   27  1991-07-12        180
# 4       E. Hazard                  Eden Hazard   28  1991-01-07        175
# 46     K. Benzema                Karim Benzema   31  1987-12-19        185
# 161      L. Jović                   Luka Jović   21  1997-12-23        182
#
#      weight_kg nationality         club  ...   lwb   ldm   cdm   rdm   rwb  \
# 100         82       Wales  Real Madrid  ...  72+3  69+3  69+3  69+3  72+3
# 106         75    Colombia  Real Madrid  ...  67+3  67+3  67+3  67+3  67+3
# 4           74     Belgium  Real Madrid  ...  66+3  63+3  63+3  63+3  66+3
# 46          81      France  Real Madrid  ...  62+3  62+3  62+3  62+3  62+3
# 161         85      Serbia  Real Madrid  ...  55+2  53+2  53+2  53+2  55+2
#
#        lb   lcb    cb   rcb    rb
# 100  70+3  66+3  66+3  66+3  70+3
# 106  62+3  57+3  57+3  57+3  62+3
# 4    61+3  49+3  49+3  49+3  61+3
# 46   58+3  54+3  54+3  54+3  58+3
# 161  51+2  47+2  47+2  47+2  51+2
#
# [5 rows x 104 columns]

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 18      155862  https://sofifa.com/player/155862/sergio-ramos-...
# 42      200145  https://sofifa.com/player/200145/carlos-henriq...
# 76      201535  https://sofifa.com/player/201535/raphael-varan...
# 94      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 332     240130  https://sofifa.com/player/240130/eder-gabriel-...
#
#        short_name                          long_name  age         dob  \
# 18   Sergio Ramos                Sergio Ramos García   33  1986-03-30
# 42       Casemiro  Carlos Henrique Venancio Casimiro   27  1992-02-23
# 76      R. Varane                     Raphaël Varane   26  1993-04-25
# 94       Carvajal              Daniel Carvajal Ramos   27  1992-01-11
# 332  Éder Militão               Éder Gabriel Militão   21  1998-01-18
#
#      height_cm  weight_kg nationality         club  ...   lwb   ldm   cdm  \
# 18         184         82       Spain  Real Madrid  ...  80+3  84+3  84+3
# 42         185         84      Brazil  Real Madrid  ...  78+3  84+3  84+3
# 76         191         81      France  Real Madrid  ...  74+3  79+3  79+3
# 94         173         73       Spain  Real Madrid  ...  83+3  82+3  82+3
# 332        186         78      Brazil  Real Madrid  ...  78+2  76+2  76+2
#
#       rdm   rwb    lb   lcb    cb   rcb    rb
# 18   84+3  80+3  82+3  87+3  87+3  87+3  82+3
# 42   84+3  78+3  79+3  84+3  84+3  84+3  79+3
# 76   79+3  74+3  77+3  83+3  83+3  83+3  77+3
# 94   82+3  83+3  83+3  80+3  80+3  80+3  83+3
# 332  76+2  78+2  78+2  79+2  79+2  79+2  78+2
#
# [5 rows x 104 columns]

# %%
real_madrid['nationality'].value_counts()
# Out:
# nationality
# Spain                 13
# Brazil                 6
# France                 3
# Belgium                2
# Croatia                1
# Germany                1
# Costa Rica             1
# Wales                  1
# Colombia               1
# Serbia                 1
# Dominican Republic     1
# Uruguay                1
# Japan                  1
# Name: count, dtype: int64

# %%
argentina = fifa[fifa['nationality']=='Argentina']
argentina.head()
argentina['short_name'].value_counts()
# Out:
# short_name
# J. Correa        3
# J. Rodríguez     3
# D. Rodríguez     2
# C. Álvarez       2
# R. Funes Mori    2
#                 ..
# C. Menéndez      1
# J. Schunke       1
# R. Delgado       1
# E. Cerutti       1
# N. Forastiero    1
# Name: count, Length: 851, dtype: int64

# %%
argentina = argentina[['short_name','long_name','wage_eur']]
argentina.head(50)
# Out:
#         short_name                          long_name  wage_eur
# 0         L. Messi     Lionel Andrés Messi Cuccittini    565000
# 17       S. Agüero  Sergio Leonel Agüero del Castillo    300000
# 23       P. Dybala        Paulo Bruno Exequiel Dybala    215000
# 66     A. Di María    Ángel Fabián Di María Hernández    150000
# 93       M. Icardi        Mauro Emanuel Icardi Rivero    115000
# 97        A. Gómez              Alejandro Darío Gómez     92000
# 98      G. Higuaín            Gonzalo Gerardo Higuaín    175000
# 159    G. Lo Celso                   Giovani Lo Celso    105000
# 210       E. Garay             Ezequiel Marcelo Garay     48000
# 213      E. Banega      Éver Maximiliano David Banega     26000
# 224    N. Otamendi            Nicolás Hernán Otamendi    145000
# 253      A. Correa                       Ángel Correa     59000
# 266  N. Tagliafico       Nicolás Alejandro Tagliafico     27000
# 292      L. Biglia               Lucas Rodrigo Biglia     49000
# 329    L. Martínez                   Lautaro Martínez     61000
# 342       G. Rulli                     Gerónimo Rulli     32000
# 372       L. López                     Lisandro López     25000
# 392      N. Gaitán      Osvaldo Nicolás Fabián Gaitán     13000
# 402     F. Vázquez                     Franco Vázquez     24000
# 405       M. Acuña                Marcos Javier Acuña     21000
# 434      J. Correa                     Joaquín Correa     53000
# 441     L. Paredes                    Leandro Paredes     79000
# 456     E. Andrada                    Esteban Andrada     24000
# 460     W. Benítez                     Walter Benítez     30000
# 465     M. Lanzini                     Manuel Lanzini     88000
# 491  J. Mascherano        Javier Alejandro Mascherano     13000
# 504      E. Lamela                        Erik Lamela     94000
# 508      S. Romero               Sergio Germán Romero     85000
# 510      I. Piatti                     Ignacio Piatti     13000
# 519       F. Fazio              Federico Julián Fazio     45000
# 522     D. Perotti                      Diego Perotti     54000
# 523      L. Pratto                 Lucas David Pratto     33000
# 526   M. Musacchio              Mateo Pablo Musacchio     44000
# 536      E. Salvio             Eduardo Antonio Salvio     31000
# 539     R. Pereyra                    Roberto Pereyra     78000
# 558      F. Armani                      Franco Armani     22000
# 559     I. Marcone                       Iván Marcone     29000
# 581       C. Pavón               Cristian David Pavón     11000
# 635      L. Alario                       Lucas Alario     70000
# 640    G. Pezzella          Germán Alejandro Pezzella     55000
# 671     E. Lavezzi              Ezequiel Iván Lavezzi     21000
# 675      D. Valeri                Diego Hernán Váleri     11000
# 681   A. Fernández           Augusto Matías Fernández     19000
# 682      N. Guzmán              Nahuel Ignacio Guzmán     56000
# 707     J. Pastore              Javier Matías Pastore     47000
# 719       E. Pérez                         Enzo Pérez     26000
# 737   D. Benedetto                    Darío Benedetto     46000
# 738      L. Sigali                    Leonardo Sigali     24000
# 757     M. Zaracho                     Matías Zaracho     18000
# 785     R. De Paul             Rodrigo Javier De Paul     21000

# %%
argentina.tail(50)
# Out:
#              short_name                     long_name  wage_eur
# 15506       E. González             Emiliano González      1000
# 15590          N. Femia                 Nicolás Femia      2000
# 15594         J. Bolado              Juan Cruz Bolado      1000
# 15608       L. Calderón                Lucas Calderón      2000
# 15610      M. Centurión         Maximiliano Centurión      1000
# 15639           A. Sosa                     Alan Sosa      2000
# 15708     M. Burruchaga              Mauro Burruchaga      1000
# 15713          L. Vella                 Leandro Vella      2000
# 15878         J. Romero                  Jonás Romero      1000
# 15879       J. Blazquez              Joaquin Blazquez      2000
# 15883      L. Ingolotti        Luis Ignacio Ingolotti      1000
# 15894         T. Cuello          Tomás Esteban Cuello      1000
# 15910       L. González                Lucas González      2000
# 15913         L. Guzmán                Lautaro Guzmán      2000
# 15975  M. Ahumada Acuña          Matías Ahumada Acuña      2000
# 16014         F. Almada                Facundo Almada      2000
# 16015          I. Smith                    Iván Smith      2000
# 16066        D. Mercado                 Diego Mercado      3000
# 16071         J. Farias               Jonathan Farias      2000
# 16073        L. Cabrera              Lisandro Cabrera      1000
# 16088         I. Chicco      Ignacio Francisco Chicco      1000
# 16112       T. Amilivia               Thomas Amilivia      2000
# 16156           L. Ríos                    Lucas Ríos      2000
# 16182        N. Insfrán       Nelson Federico Insfrán      2000
# 16196        M. Rouzies                Marcos Rouzies      2000
# 16197       C. Villalba               Carlos Villalba      2000
# 16213   F. Pizzicanella           Franco Pizzicanella      1000
# 16227         E. Cuevas                Emanuel Cuevas      2000
# 16285           C. Fara                     Caín Fara      2000
# 16336       F. Melivilo    Facundo Emmanuel Melivillo      2000
# 16370          F. Godoy           Franco Lionel Godoy      1000
# 16384           R. Ruiz                   Ramiro Ruiz      1000
# 16412         A. Manzur                Agustín Manzur      1000
# 16447       F. González               Franco González      2000
# 16467        G. Galoppo              Giuliano Galoppo      2000
# 16717    S. Ramos Mingo          Santiago Ramos Mingo      1000
# 16725         A. Obando                Agustín Obando      2000
# 16808        N. Cordero               Nicolás Cordero      2000
# 16895           M. Miño          Marcelo Agustín Miño      1000
# 16930         J. Chacón               Jonathan Chacón      2000
# 17075        L. Morales              Leonardo Morales      2000
# 17097       C. Albornoz               Camilo Albornoz      1000
# 17114         I. Ibáñez                   Iván Ibáñez      1000
# 17345        B. Mendoza                 Bryan Mendoza      2000
# 17412          T. Durso                   Tomás Durso      1000
# 17526           J. Hass                  Joaquín Hass      1000
# 17580          G. Bruna  Gerardo Alfredo Bruna Blanco      1000
# 17657       R. Ferrario               Rafael Ferrario      1000
# 17712    L. Finochietto           Leandro Finochietto      1000
# 17922     N. Forastiero            Nicolás Forastiero      1000

# %%
argentina = fifa[fifa['nationality']=='Brazil']
argentina.head(10)
# Out:
#     sofifa_id                                         player_url  \
# 2      190871  https://sofifa.com/player/190871/neymar-da-sil...
# 13     212831  https://sofifa.com/player/212831/alisson-ramse...
# 25     210257  https://sofifa.com/player/210257/ederson-santa...
# 42     200145  https://sofifa.com/player/200145/carlos-henriq...
# 44     135507  https://sofifa.com/player/135507/fernando-luiz...
# 45     164240  https://sofifa.com/player/164240/thiago-emilia...
# 56     207865  https://sofifa.com/player/207865/marcos-aoas-c...
# 63     201942  https://sofifa.com/player/201942/roberto-firmi...
# 68     189242  https://sofifa.com/player/189242/philippe-cout...
# 81     209499  https://sofifa.com/player/209499/fabio-henriqu...
#
#          short_name                            long_name  age         dob  \
# 2         Neymar Jr        Neymar da Silva Santos Junior   27  1992-02-05
# 13          Alisson                Alisson Ramses Becker   26  1992-10-02
# 25          Ederson            Ederson Santana de Moraes   25  1993-08-17
# 42         Casemiro    Carlos Henrique Venancio Casimiro   27  1992-02-23
# 44      Fernandinho                   Fernando Luiz Rosa   34  1985-05-04
# 45     Thiago Silva             Thiago Emiliano da Silva   34  1984-09-22
# 56       Marquinhos                  Marcos  Aoás Corrêa   25  1994-05-14
# 63  Roberto Firmino  Roberto Firmino Barbosa de Oliveira   27  1991-10-02
# 68         Coutinho            Philippe Coutinho Correia   27  1992-06-12
# 81          Fabinho               Fábio Henrique Tavares   25  1993-10-23
#
#     height_cm  weight_kg nationality                 club  ...   lwb   ldm  \
# 2         175         68      Brazil  Paris Saint-Germain  ...  66+3  61+3
# 13        191         91      Brazil            Liverpool  ...   NaN   NaN
# 25        188         86      Brazil      Manchester City  ...   NaN   NaN
# 42        185         84      Brazil          Real Madrid  ...  78+3  84+3
# 44        179         67      Brazil      Manchester City  ...  80+3  84+3
# 45        183         82      Brazil  Paris Saint-Germain  ...  77+3  82+3
# 56        183         75      Brazil  Paris Saint-Germain  ...  79+3  82+3
# 63        181         76      Brazil            Liverpool  ...  72+3  73+3
# 68        172         68      Brazil    FC Bayern München  ...  70+3  68+3
# 81        188         78      Brazil            Liverpool  ...  81+3  84+3
#
#      cdm   rdm   rwb    lb   lcb    cb   rcb    rb
# 2   61+3  61+3  66+3  61+3  46+3  46+3  46+3  61+3
# 13   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 42  84+3  84+3  78+3  79+3  84+3  84+3  84+3  79+3
# 44  84+3  84+3  80+3  80+3  82+3  82+3  82+3  80+3
# 45  82+3  82+3  77+3  78+3  84+3  84+3  84+3  78+3
# 56  82+3  82+3  79+3  81+3  83+3  83+3  83+3  81+3
# 63  73+3  73+3  72+3  69+3  67+3  67+3  67+3  69+3
# 68  68+3  68+3  70+3  66+3  58+3  58+3  58+3  66+3
# 81  84+3  84+3  81+3  81+3  83+3  83+3  83+3  81+3
#
# [10 rows x 104 columns]
