# %% [markdown]
# # World Vaccination Analysis

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import datetime as dt

# %%
vaccine = pd.read_csv('country_vaccinations.csv', parse_dates=['date'], dayfirst=True)
# Out:
# C:\Users\Maira\AppData\Local\Temp\ipykernel_10840\2833178054.py:1: UserWarning: Parsing dates in %Y-%m-%d format when dayfirst=True was specified. Pass `dayfirst=False` or specify a format to silence this warning.
#   vaccine = pd.read_csv('country_vaccinations.csv', parse_dates=['date'], dayfirst=True)

# %%
vaccine.head()
# Out:
#        country iso_code       date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG 2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG 2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG 2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG 2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG 2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
vaccine.tail()
# Out:
#         country iso_code       date  total_vaccinations  people_vaccinated  \
# 86507  Zimbabwe      ZWE 2022-03-25           8691642.0          4814582.0
# 86508  Zimbabwe      ZWE 2022-03-26           8791728.0          4886242.0
# 86509  Zimbabwe      ZWE 2022-03-27           8845039.0          4918147.0
# 86510  Zimbabwe      ZWE 2022-03-28           8934360.0          4975433.0
# 86511  Zimbabwe      ZWE 2022-03-29           9039729.0          5053114.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 86507                3473523.0                139213.0             69579.0
# 86508                3487962.0                100086.0             83429.0
# 86509                3493763.0                 53311.0             90629.0
# 86510                3501493.0                 89321.0            100614.0
# 86511                3510256.0                105369.0            103751.0
#
# ...

# %%
vaccine['vaccines'].value_counts()
# Out:
# vaccines
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                     7608
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                      6263
# Oxford/AstraZeneca                                                                6022
# Oxford/AstraZeneca, Pfizer/BioNTech                                               4629
# Johnson&Johnson, Moderna, Novavax, Oxford/AstraZeneca, Pfizer/BioNTech            3564
#                                                                                   ...
# Johnson&Johnson, Oxford/AstraZeneca, Sinovac                                       312
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V                   311
# Johnson&Johnson, Moderna                                                           251
# Johnson&Johnson, Pfizer/BioNTech, Sinopharm/Beijing                                228
# EpiVacCorona, Oxford/AstraZeneca, QazVac, Sinopharm/Beijing, Sputnik V, ZF2001     190
# ...

# %%
vaccine.shape
# Out:
# (86512, 15)

# %%
vaccine = vaccine[['country','date','total_vaccinations','people_vaccinated','vaccines']]
vaccine.sample(10)
# Out:
#                    country       date  total_vaccinations  people_vaccinated  \
# 84835                Wales 2021-08-02           4371394.0          2297398.0
# 47521             Malaysia 2021-03-05            112428.0           112371.0
# 84169            Venezuela 2022-01-04                 NaN                NaN
# 74347                Sudan 2021-08-14                 NaN                NaN
# 62335               Poland 2021-02-07           1656708.0          1206212.0
# 13870               Canada 2022-03-26          82029183.0         32659899.0
# 79043  Trinidad and Tobago 2022-01-25           1470094.0           731209.0
# 47063           Madagascar 2021-12-26                 NaN                NaN
# 30495               Greece 2021-09-13          11728334.0          6281530.0
# 46136           Luxembourg 2021-06-15            452778.0           273094.0
#
#                                                 vaccines
# 84835       Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# ...

# %%
lux = vaccine[vaccine.country == 'Luxembourg']
lux.head()
lux.shape
lux.tail()
# Out:
#           country       date  total_vaccinations  people_vaccinated  \
# 46416  Luxembourg 2022-03-22           1278891.0           480182.0
# 46417  Luxembourg 2022-03-23           1279145.0           480197.0
# 46418  Luxembourg 2022-03-24           1279437.0           480223.0
# 46419  Luxembourg 2022-03-25           1279844.0           480249.0
# 46420  Luxembourg 2022-03-26           1280144.0           480279.0
#
#                                                 vaccines
# 46416  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46417  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46418  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46419  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46420  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...

# %%
#predicting
from sklearn.model_selection import train_test_split

# %%
lux['date'] = lux['date'].map(dt.datetime.toordinal)
# Out:
# C:\Users\Maira\AppData\Local\Temp\ipykernel_10840\2279922907.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   lux['date'] = lux['date'].map(dt.datetime.toordinal)

# %%
lux.head()
lux.tail()
# Out:
#           country    date  total_vaccinations  people_vaccinated  \
# 46416  Luxembourg  738236           1278891.0           480182.0
# 46417  Luxembourg  738237           1279145.0           480197.0
# 46418  Luxembourg  738238           1279437.0           480223.0
# 46419  Luxembourg  738239           1279844.0           480249.0
# 46420  Luxembourg  738240           1280144.0           480279.0
#
#                                                 vaccines
# 46416  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46417  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46418  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46419  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...
# 46420  Johnson&Johnson, Moderna, Oxford/AstraZeneca, ...

# %%
#independent variable
x=lux['date']
#dependent variable
y=lux['people_vaccinated']

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
print(np.isnan(y_train).any())  # Check if NaNs are present
print(np.where(np.isnan(y_train)))  # Find the indices of NaNs
# Out:
# True
# (array([  1,   2,   7,  18,  24,  39,  72, 101, 115, 116, 117, 125, 127,
#        135, 175, 182, 183, 184, 198, 209, 213, 218, 251, 257, 261, 278,
#        288, 294, 297, 299], dtype=int64),)

# %%
valid_indices = ~np.isnan(y_train)
x_train = x_train[valid_indices]
y_train = y_train[valid_indices]

# %%
rf.fit(np.array(x_train).reshape(-1,1),np.array(y_train).reshape(-1,1))
# Out:
# C:\Users\Maira\anaconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
rf.predict([[738241]])
# Out:
# array([480256.03])
